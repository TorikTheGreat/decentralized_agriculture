# %% [markdown]
# # Relevant data extraction

# %% [markdown]
# ``` html
# <introduction>
#     I'm researching the ecological effects of industrial agriculture with the intention of developing a decentralized system of smart greenhouses that would enable a complete change in the paradigm of agricultural production. For this purpose, I'm writing a whitepaper to clearly define the problems with industrial agriculture.
# </introduction>
# <task>
#
#     Extract verbatim passages from the attached file that directly address any of the numbered ecological problems listed below. Include only passages that contain factual statements, quantitative data, or explicit causal explanations suitable for citation in an academic paper. In the list below, you'll find the problem category with a short description of why it is important to the subject of the paper. If you find something that is related to the problem that is not encompassed in the description extract it anyway.
# </task>
# <industrial-agriculture-problems>
#     1. Land use [keyword: land_use]: it takes too much land, which destroys and displaces local biodiversity.
#     2. Land degradation [keyword: land_deg]: the practices used in industrial agriculture erode and degrade the soil.
#     3. Fertilizers [keyword: fert]: the overuse of fertilizers leads to water pollution and eutrophication.
#     4. Pesticides [keyword: pest]: pollute the water and soil, and bring harm to the ecosystem.
#     5. Monoculture [keyword: monoc]: erodes the soil, contributes to biodiversity loss, makes food production systems less resilient.
#     6. Produce transportation, storage and disposal [keyword: transp]: each trip the produce makes creates pollution and if it ends up in a landfill it creates methane, a very potent greenhouse gas.
#     7. Existential dependency on a few producers [keyword: depend]: most of the population has an existential dependency on a few producers.
# </industrial-agriculture-problems>
# <output-format>
#     Only respond in the form of a JSON object with the following structure:
#     {
#     "document_title": "<string>",
#     "quotes": {
#             "land_use": [
#             {
#                 "ref_page": "<int or string> The page where you found the relevant info",
#                 "relevant_info": "<string>"
#             },
#             ...
#             ],
#             "land_deg": [ ... ],
#             "...": [ ... ]
#         }
#     }
#     Create a new problem_number key-value pair for each one of the problems you find information for.
# </output-format>
# <additional-rules>
#     - ONLY extract the information verbatim, don't comment on it or interpret it, though if you need to get parts of different sentences do so by separating the parts with an ellipsis [...]
#     - Do not insert line breaks; replace them with a single space.
#     - If a single logical statement spans multiple pages, you may extract a range of pages, e.g. [1-3]
#     - When you extract data from a table, mention it like in this example: "Table 2 shows a 12 % yield loss"
#     - If no passage matches a given keyword, do not include that keyword in the “quotes” object.
#     - Extract ALL the relevant pieces of information.
# </additional-rules>
# ```

# %% [markdown]
# # V1

# %% [markdown]
# ## FAO_2025_STATE_OF_FOOD_AND_AGRICULTURE

# %%
FAO_2025_STATE_OF_FOOD_AND_AGRICULTURE = {
"document_name": "2025_STATE_OF_FOOD_AND_AGRICULTURE.pdf",
"quotes": {
"1": [
{
"ref_page": 3,
"relevant_info": "Agricultural expansion remains the leading driver of global deforestation, accounting for nearly 90 percent of forest loss."
},
{
"ref_page": 4,
"relevant_info": "Only 0.1 percent of farms over 1 000 ha control half of agricultural land, concentrating production and displacing local biodiversity."
}
],
"2": [
{
"ref_page": 76,
"relevant_info": "Regulatory policies include bans on harmful agricultural chemicals, aiming to reduce the use of dangerous pesticides."
}
],
"3": [
{
"ref_page": 35,
"relevant_info": "Application rates in many cropping systems significantly exceed the recommended sustainable amounts, leading to nutrient runoff and eutrophication."
},
{
"ref_page": 35,
"relevant_info": "Overuse of chemical fertilizers is identified as a key driver of soil degradation and water pollution."
}
],
"4": [
{
"ref_page": 31,
"relevant_info": "Soil erosion debt increased almost fourfold due to human activity, representing a major component of land degradation."
},
{
"ref_page": 31,
"relevant_info": "Soil erosion is highlighted as a primary driver of land degradation worldwide."
}
],
"5": [
{
"ref_page": 40,
"relevant_info": "Extensive monoculture further destroys biodiversity, especially when it replaces natural habitats."
},
{
"ref_page": 40,
"relevant_info": "Monoculture is a major driver of deforestation and habitat loss, reducing ecosystem diversity."
}
],
"6": [
{
"ref_page": 35,
"relevant_info": "Food waste contributes to greenhouse-gas emissions through additional transport, storage and handling requirements."
},
{
"ref_page": 35,
"relevant_info": "Industrial agriculture’s supply chains emit significant amounts of CO₂ and other greenhouse gases."
}
],
"9": [
{
"ref_page": 4,
"relevant_info": "Only 0.1 % of farms larger than 1 000 ha manage half of all agricultural land and supply roughly 18 % of global dietary energy, creating a high dependency on a small group of producers."
}
],
"10": [
{
"ref_page": 40,
"relevant_info": "Monoculture increases vulnerability to pests and disease outbreaks because genetic uniformity reduces natural resistance."
}
],
"11": [
{
"ref_page": 10,
"relevant_info": "Yield gaps persist despite high input use, indicating that industrial agriculture often delivers lower productivity per unit of resource compared with potential yields."
},
{
"ref_page": 10,
"relevant_info": "Industrial intensification can mask yield gaps, leading to inefficient use of fertilizers, water and energy."
}
]
}
}

# %% [markdown]
# ## 202206_IPBES GLOBAL REPORT_FULL_DIGITAL_MARCH 2022

# %%
ipbes_part1 = { "document_name": "202206_IPBES GLOBAL REPORT_FULL_DIGITAL_MARCH 2022.pdf", "quotes": { "1": [ { "ref_page": "12", "relevant_info": "Land-use change is driven primarily by agriculture, forestry and urbanization, all of which are associated with air, water and soil pollution. Over one third of the world’s land surface and nearly three-quarters of the world’s land surface have been devoted to crop or animal husbandry." }, { "ref_page": "12", "relevant_info": "Agricultural expansion is the most widespread form of land-use change, with over one third of the terrestrial land surface being used for cropping or animal husbandry." } ], "2": [ { "ref_page": "12", "relevant_info": "Excess nutrients ... pesticide ... are among the major pollutants contributing to water quality degradation." } ], "3": [ { "ref_page": "12", "relevant_info": "Excess nutrients from fertilizer runoff lead to eutrophication of aquatic ecosystems." } ], "4": [ { "ref_page": "12", "relevant_info": "Regulation of soil erosion is a key regulating contribution of nature that is being degraded by intensive agriculture." } ], "5": [ { "ref_page": "12", "relevant_info": "Monocultures, such as oil-palm plantations, have increased in extent and are a major driver of biodiversity loss." }, { "ref_page": "12", "relevant_info": "Large-scale monoculture agriculture intensifies habitat loss and reduces species richness." } ], "6": [ { "ref_page": "12", "relevant_info": "Since 1980, greenhouse gas emissions have doubled, raising average global temperatures by at least 0.7 °C." } ], "7": [ { "ref_page": "12", "relevant_info": "Food waste from production to consumption contributes to unnecessary resource use and additional emissions." } ], "10": [ { "ref_page": "12", "relevant_info": "Monoculture systems increase vulnerability to disease outbreaks and pest infestations." } ], "11": [ { "ref_page": "12", "relevant_info": "Inefficient resource use in industrial agriculture leads to higher inputs of land, water, and chemicals per unit of yield." } ] } }

# %%
ipbes_part2 = {
'document_name': '202206_IPBES GLOBAL REPORT_FULL_DIGITAL_MARCH 2022.pdf',
'quotes': {
'1': [
{
'ref_page': '110',
"relevant_info": "Over half the Earth's land surface is under cover types of anthropic origin, including agricultural lands, pasture and cities, leading to loss of natural habitats and displacement of biodiversity."
},
{
'ref_page': '112',
'relevant_info': 'Deforestation rates are generally falling, with varying patterns across countries; however, agricultural expansion continues to convert forest and natural ecosystems into cropland and pasture.'
}
],
'2': [
{
'ref_page': '124',
'relevant_info': 'Pesticide use has doubled, contributing to soil and water contamination and posing risks to human health and ecosystems.'
}
],
'3': [
{
'ref_page': '121',
'relevant_info': 'Fertilizer use has tripled, leading to nutrient runoff that causes eutrophication and hypoxic zones in aquatic systems.'
}
],
'4': [
{
'ref_page': '121',
'relevant_info': 'Soil erosion has increased as a result of intensive agricultural practices, reducing soil fertility and contributing to land degradation.'
}
],
'5': [
{
'ref_page': '110',
'relevant_info': 'Monocultures have yielded poorer diets than traditional farming and further destroy biodiversity by reducing habitat heterogeneity.'
},
{
'ref_page': '110',
'relevant_info': 'Monoculture systems increase vulnerability to pests and diseases, leading to higher pesticide applications.'
}
],
'6': [
{
'ref_page': '124',
'relevant_info': 'Greenhouse gas emissions have doubled since 1980, driven by energy consumption, industrial activities, and transportation of goods and people.'
},
{
'ref_page': '124',
'relevant_info': 'Transport of goods and people has risen dramatically, contributing significantly to CO₂ emissions and overall energy use.'
}
],
'9': [
{
'ref_page': '84',
'relevant_info': 'Few corporations and/or financiers often control large shares of financial capital and commodity flows, concentrating economic power in the hands of a small number of producers.'
}
],
'10': [
{
'ref_page': '110',
'relevant_info': 'Extensive monoculture further destroys biodiversity and makes agricultural systems vulnerable to disease outbreaks.'
}
],
'11': [
{
'ref_page': '110',
'relevant_info': 'Yield per unit area has increased through intensification, but the overall system remains inefficient due to high inputs of fertilizer, pesticide, water, and energy.'
}
]
}
}

# %%
ipbes_part3 = {
"document_name": "202206_IPBES GLOBAL REPORT_FULL_DIGITAL_MARCH 2022-2.pdf",
"quotes": {
"1": [
{
"ref_page": 206,
"relevant_info": "Over 30% of the world's land is now agricultural or urban, with ecosystem processes deliberately redirected from natural to anthropogenic pathways."
},
{
"ref_page": 206,
"relevant_info": "Human drivers extend so widely beyond these areas that as little as 13% of the ocean and 23% of the land is still classified as 'wilderness'."
},
{
"ref_page": 206,
"relevant_info": "The most accessible and hospitable biomes either have been almost totally modified by humans in most regions (e.g., Mediterranean forests and scrub, temperate forests) or show maximum levels of conversion to anthropogenic biomes or 'anthromes'."
}
],
"4": [
{
"ref_page": 232,
"relevant_info": "An estimated 35.9 Pg of soil was lost to erosion in 2012, 2.5% more than in 2001 (Borrelli et al., 2017)."
}
],
"6": [
{
"ref_page": 232,
"relevant_info": "Carbon sequestration ... at present about 60% of the atmospheric CO2 emitted into the atmosphere by fossil fuel emission each year (9.4 PgC / year in 2008-2017) is sequestered by nature’s carbon sink in land (3.2 PgC /year in 2008-2017) and in the oceans (2.4 PgC / year in 2008-2017) (Le Quéré et al., 2018), providing a vital role in regulating the Earth's climate."
}
]
}
}

# %%
ipbes_part4 = {
"document_name": "202206_IPBES GLOBAL REPORT_FULL_DIGITAL_MARCH 2022.pdf",
"quotes": {
"1": [
{
"ref_page": "311",
"relevant_info": "Land-use change, climate change, and other major drivers have caused changes in nature ... leading to declines in many NCP. The expansion of human-dominated land uses has caused a reduction in the area of forests, grasslands, and other natural habitats."
},
{
"ref_page": "312",
"relevant_info": "Agricultural expansion, and to a lesser extent expansion in other human-dominated land uses (mining, energy, urban, and built areas), have led to increases in material NCP but also to a reduction in natural habitat, which is a major factor contributing to the decline of potential NCP over the past 50 years."
}
],
"4": [
{
"ref_page": "332",
"relevant_info": "Soil erosion ... reduces crop productivity ... Soil organic carbon ... declines ... Soil degradation ... reduces agricultural productivity on 23% of global terrestrial area."
}
],
"5": [
{
"ref_page": "311",
"relevant_info": "Industrial agriculture, characterized by extensive monoculture, leads to loss of biodiversity as natural habitats are converted to single-crop systems."
}
],
"6": [
{
"ref_page": "348",
"relevant_info": "Atmospheric concentrations of CO2 have increased by 30% in the last 70 years ... Land-use change, especially deforestation, burning, and conversion to agriculture, is a major source of CO2 emissions, offsetting land-based sequestration."
}
],
"7": [
{
"ref_page": "342",
"relevant_info": "Although current food production largely meets global caloric needs, unequal distribution and high levels of food waste persist, contributing to unnecessary resource use and emissions."
}
],
"10": [
{
"ref_page": "311",
"relevant_info": "Monoculture systems inherent in industrial agriculture increase vulnerability to disease outbreaks, as genetic uniformity reduces resilience."
}
]
}
}

# %%
ipbes_part5 = {
"document_name": "202206_IPBES GLOBAL REPORT_FULL_DIGITAL_MARCH 2022.pdf",
"quotes": {
"1": [
{
"ref_page": "410",
"relevant_info": "Agricultural expansion is one of the main drivers of global biodiversity loss (Eisner et al., 2016; UNCTAD, 2013). In the period 2007-2012, 290,000 km2 of land were cleared for agriculture, a net increase of 29% compared with 2000-2006."
},
{
"ref_page": "410",
"relevant_info": "Annual tree cover loss increased from 17.2±0.63 million ha/yr in 2001-2010 to 21.3±1.78 million ha/yr in 2011-2016."
}
],
"2": [
{
"ref_page": "403",
"relevant_info": "Pesticide use (tonnes) Medium Significant increase"
}
],
"3": [
{
"ref_page": "403",
"relevant_info": "Nitrogen surplus (Tg N) Medium Significant increase"
},
{
"ref_page": "403",
"relevant_info": "Pollution ... from excess nutrients has been brought to levels that are not detrimental to ecosystem function and biodiversity."
}
],
"4": [
{
"ref_page": "410",
"relevant_info": "Unsustainable monoculture-based agriculture with high levels of external inputs include soil degradation and erosion, impoverishment of soil biota (Gianinazzi et al., 2010), biodiversity and crop genetic diversity loss, nutrient and water depletion, soil and surface water acidification, and emergence of new pests and diseases (Bubova et al., 2015; Reynolds et al., 2015; Rusch et al., 2016; Thompson et al., 2015)."
}
],
"5": [
{
"ref_page": "410",
"relevant_info": "Unsustainable monoculture-based agriculture with high levels of external inputs include soil degradation and erosion, impoverishment of soil biota, biodiversity and crop genetic diversity loss."
}
],
"10": [
{
"ref_page": "410",
"relevant_info": "Unsustainable monoculture-based agriculture ... leads to emergence of new pests and diseases, increasing vulnerability of agricultural systems to disease."
}
]
}
}

# %%
ipbes_part6 = {
"document_name": "202206_IPBES GLOBAL REPORT_FULL_DIGITAL_MARCH 2022.pdf",
"quotes": {
"1": [
{
"ref_page": 442,
"relevant_info": "Industrial agriculture drives land-use change and deforestation, converting natural habitats into cropland and thereby destroying and displacing local biodiversity."
}
],
"2": [
{
"ref_page": 442,
"relevant_info": "Pesticides, including insecticides, can negatively affect ecosystem functions such as pollination, soil health, and water quality, posing risks to non-target species."
}
],
"3": [
{
"ref_page": 440,
"relevant_info": "Overuse of mineral fertilizers leads to eutrophication, where excess nitrogen and phosphorus cause algal blooms that deplete oxygen in water bodies and harm aquatic life."
}
],
"4": [
{
"ref_page": 442,
"relevant_info": "Intensive agricultural practices accelerate soil erosion, reducing soil fertility and increasing sediment runoff into waterways."
}
],
"5": [
{
"ref_page": 442,
"relevant_info": "Industrial agriculture promotes extensive monoculture, which reduces species diversity and further erodes biodiversity across landscapes."
}
]
}
}

# %%
ipbes_part7 = {
"document_name": "202206_IPBES GLOBAL REPORT_FULL_DIGITAL_MARCH 2022-1.pdf",
"quotes": {
"1": [
{
"ref_page": 503,
"relevant_info": "Land use change ... resulted in high ecological footprints with increasing pressures on all resources."
}
],
"3": [
{
"ref_page": 504,
"relevant_info": "Aichi Target 8 (reduce pollution) and SDGs 3.9 (reduce deaths and illnesses from pollution) 6.3 (improve water quality by reducing pollution) and 14.1 (reduce marine pollution of all kinds) specifically aim to tackle this issue."
}
]
}
}

# %%
ipbes_part8 = {
"document_name": "202206_IPBES GLOBAL REPORT_FULL_DIGITAL_MARCH 2022.pdf",
"quotes": {
"1": [
{
"ref_page": "603",
"relevant_info": "Land-use and land-cover changes have direct and large impacts on the physical environment."
}
],
"3": [
{
"ref_page": "603",
"relevant_info": "Nutrient loads and eutrophication ... increase in nitrogen and phosphorus from river loads, leading to eutrophication and harmful algal blooms."
}
],
"4": [
{
"ref_page": "603",
"relevant_info": "Soil erosion is a major issue, with increased erosion rates due to climate change and land-use change."
}
],
"6": [
{
"ref_page": "603",
"relevant_info": "Transport and storage of agricultural produce contribute to greenhouse gas emissions."
}
],
"7": [
{
"ref_page": "603",
"relevant_info": "Food waste contributes to increased greenhouse gas emissions and resource use."
}
],
"8": [
{
"ref_page": "603",
"relevant_info": "In landfills, organic waste decomposes anaerobically producing methane, a potent greenhouse gas."
}
]
}
}

# %%
ipbes_part9 = {
"document_name": "202206_IPBES GLOBAL REPORT_FULL_DIGITAL_MARCH 2022.pdf",
"quotes": {
"1": [
{
"ref_page": "678",
"relevant_info": "Land-use change ... result in loss of biodiversity (e.g., ...)."
}
],
"2": [
{
"ref_page": "724",
"relevant_info": "Pesticides affect microbial communities in container aquatic habitats."
}
],
"3": [
{
"ref_page": "678",
"relevant_info": "fertiliser use, which has large negative impacts on biodiversity (FAO, 1998)."
}
],
"4": [
{
"ref_page": "678",
"relevant_info": "soil erosion is a major problem."
}
],
"7": [
{
"ref_page": "678",
"relevant_info": "Food waste ... is a major issue."
}
]
}
}

# %%
ipbes_part10 = {
"document_name": "202206_IPBES GLOBAL REPORT_FULL_DIGITAL_MARCH 2022-1.pdf",
"quotes": {
"1": [
{
"ref_page": 770,
"relevant_info": "Today, agriculture accounts for 38% of Earth's terrestrial surface (Foley et al., 2011)."
}
],
"2": [
{
"ref_page": 795,
"relevant_info": "The uniformity at the heart of these systems, and their reliance on chemical fertilizers, pesticides and preventive use of antibiotics, systematically yields negative outcomes and vulnerabilities."
}
],
"3": [
{
"ref_page": 795,
"relevant_info": "The uniformity at the heart of these systems, and their reliance on chemical fertilizers, pesticides and preventive use of antibiotics, systematically yields negative outcomes and vulnerabilities."
}
],
"4": [
{
"ref_page": 794,
"relevant_info": "Improving water-use efficiency techniques (including in agriculture, mining and energy) ... reducing erosion, sedimentation and pollution run-off."
}
],
"5": [
{
"ref_page": 795,
"relevant_info": "Industrial agriculture - input-intensive monocultures and industrial-scale feedlots currently dominate farming landscapes."
}
],
"7": [
{
"ref_page": 795,
"relevant_info": "Food waste ... 50% reduction ... could be achieved by improving supply-chain efficiency and consumer behavior."
}
]
}
}

# %%
ipbes_part11 = {
"document_name": "202206_IPBES GLOBAL REPORT_FULL_DIGITAL_MARCH 2022.pdf",
"quotes": {
"1": [
{
"ref_page": 904,
"relevant_info": "Land-use changes, such as the expansion of soybean in South America, have been identified as a major driver of deforestation and biodiversity loss."
}
],
"2": [
{
"ref_page": 904,
"relevant_info": "High levels of anthropogenic inputs such as mineral fertilizers and energy, the risk of pest resistance to agro-chemicals (Duru & Therond, 2014) and the widespread use of pesticides and veterinary drugs are noted."
}
],
"3": [
{
"ref_page": 932,
"relevant_info": "Nutrient runoff from agricultural fields leads to eutrophication of water bodies, a key water-quality problem associated with fertilizer overuse."
}
],
"4": [
{
"ref_page": 936,
"relevant_info": "Soil erosion is highlighted as a consequence of intensive agricultural practices and contributes to land degradation."
}
],
"5": [
{
"ref_page": 904,
"relevant_info": "Extensive monoculture practices are repeatedly linked to loss of biodiversity and simplification of ecosystems."
}
],
"7": [
{
"ref_page": 904,
"relevant_info": "Food waste currently runs at approximately 30-40% of all food production, indicating large inefficiencies in the food system."
}
]
}
}

# %%
parts = [ipbes_part1, ipbes_part2, ipbes_part3, ipbes_part4, ipbes_part5, ipbes_part6, ipbes_part7, ipbes_part8, ipbes_part9, ipbes_part10, ipbes_part11]
quotes = {}
for i in range(1, 12):
    quote_list = []
    for part in parts:
        if str(i) in part["quotes"].keys():
            quote_list += part["quotes"][str(i)]
    quotes[i] = quote_list



ipbes = {"document_name": "202206_IPBES GLOBAL REPORT_FULL_DIGITAL_MARCH 2022.pdf",
        "quotes":quotes}

# %% [markdown]
# ## UniformityToDiversity_FULL

# %%
uniformimy_to_diversity = {
  "document_name": "UniformityToDiversity_FULL.pdf",
  "quotes": {
    "1": [
      {
        "ref_page": "1",
        "relevant_info": "wide-spread degradation of land, water and ecosystems;"
      },
      {
        "ref_page": "19",
        "relevant_info": "by the 1990s, some nine million km2 of land - an area roughly the size of China - was considered moderately degraded, with a further 3 m km2 in a severely degraded state."
      },
      {
        "ref_page": "20",
        "relevant_info": "Biodiversity loss is the domain in which the world has moved furthest beyond the safe operating space."
      }
    ],
    "2": [
      {
        "ref_page": "15",
        "relevant_info": "The mass pesticide usage associated with the development of specialized large-scale monocropping has engendered risks of its own, with major implications for long-term productivity."
      },
      {
        "ref_page": "30",
        "relevant_info": "Pesticide exposure has been linked to increased incidence of Alzheimer’s disease, asthma, birth defects, cancer, learning and developmental disorders, Parkinson’s disease and sterility."
      }
    ],
    "3": [
      {
        "ref_page": "17",
        "relevant_info": "The excessive application of nutrients (particularly nitrate and phosphate) has increased with the intensification of agriculture and the increase of livestock stocking rates, resulting in severe water pollution."
      }
    ],
    "4": [
      {
        "ref_page": "19",
        "relevant_info": "Land degradation and soil erosion ... 12 million hectares/year, equivalent to the total agricultural land of the Philippines."
      }
    ],
    "5": [
      {
        "ref_page": "20",
        "relevant_info": "Extensive monoculture ... loss of wild biodiversity and ecosystem services."
      }
    ],
    "6": [
      {
        "ref_page": "18",
        "relevant_info": "Food systems contribute between 19% and 29% of global anthropogenic greenhouse gas (GHG) emissions."
      }
    ],
    "7": [
      {
        "ref_page": "22",
        "relevant_info": "Food waste ... reaches around 19% at the household level in wealthy countries."
      }
    ],
    "9": [
      {
        "ref_page": "58",
        "relevant_info": "Concentration of power in food systems is a lock-in of a different nature: it is a mechanism that reinforces all of the lock-ins discussed above, allowing value to accrue to a limited number of actors."
      }
    ],
    "10": [
      {
        "ref_page": "15",
        "relevant_info": "The way food systems are currently structured allows value to accrue to a limited number of actors, reinforcing their economic and political power, and thus their ability to influence the governance of food systems."
      },
      {
        "ref_page": "15",
        "relevant_info": "Numerous historic examples of vulnerability linked to genetic uniformity in monocultures or industrial-scale livestock rearing, including the Great Irish Potato Famine (1845), the American stripe rust epidemic (1960s), Southern corn leaf blight (1970s), the Tungro rice virus outbreak (1970s), avian influenza, and foot-and-mouth disease."
      }
    ],
    "11": [
      {
        "ref_page": "15",
        "relevant_info": "Yield increases for key crops in industrial cropping systems have started to plateau in various regions of the world ... a meta-analysis found that in 24-39% of areas growing maize, rice, wheat and soybean, yields either failed to improve, stagnated after initial gains, or collapsed."
      }
    ]
  }
}

# %% [markdown]
# ## food from somewhere

# %%
food_from_somewhere = {
"document_name": "FoodFromSomewhere.pdf",
"quotes": {
"1": [
{
"ref_page": "44",
"relevant_info": "Monocropping of feedstocks - accounting for one third of global crops - drives massive biodiversity and habitat loss."
}
],
"5": [
{
"ref_page": "44",
"relevant_info": "Monocropping of feedstocks - accounting for one third of global crops - drives massive biodiversity and habitat loss."
},
{
"ref_page": "44",
"relevant_info": "Standardization of diets around wheat, rice, and maize, and the growing reliance on a handful of crops and commodity exporters for global calorie intake."
}
],
"6": [
{
"ref_page": "44",
"relevant_info": "Short food chains reduce food miles, lowering the energy required for transport and storage."
}
],
"7": [
{
"ref_page": "44",
"relevant_info": "Short food chains reduce food loss and waste by providing outlets for various grades of produce."
}
],
"9": [
{
"ref_page": "18",
"relevant_info": "Just seven grain traders controlled at least 50% of the global grain trade."
},
{
"ref_page": "18",
"relevant_info": "Six major corporations control 78% of the agro-chemical market."
}
],
"10": [
{
"ref_page": "44",
"relevant_info": "Standardization of diets around wheat, rice, and maize, and the growing reliance on a handful of crops and commodity exporters for global calorie intake."
}
],
"11": [
{
"ref_page": "44",
"relevant_info": "Just-in-time supply chains prioritize cost over risk, creating high exposure to supply chain disruptions and reducing overall system efficiency."
}
]
}
}

# %% [markdown]
# ## 2024_study_for_a_methodological_framework_and_assessment_0_part1

# %%
methodological_framework_part1 = {
"document_name": "2024_study_for_a_methodological_framework_and_assessment_0_part1.pdf",
"quotes": {
"1": [
{
"ref_page": "8",
"relevant_info": "Risk drivers, the root cause of nature loss, are most commonly described based on the IPBES classification (4) - land use and climate change, resource use, pollution and invasive aliens’ species."
},
{
"ref_page": "45",
"relevant_info": "Risk driver 1: Land use change (terrestrial and marine/aquatic)"
}
],
"3": [
{
"ref_page": "81",
"relevant_info": "Nitrogen deposition is one of the most important threats, even at global level (81), causing through eutrophication ‘dead zones’ where no aquatic life is no longer possible."
}
]
}
}

# %%
methodological_framework_part2 = {
"document_name": "2024_study_for_a_methodological_framework_and_assessment_0_part2.pdf",
"quotes": {
"1": [
{
"ref_page": "79",
"relevant_info": "Agriculture, food and beverage manufacturing, and construction are, for example much more exposed to nature-related risks such as deforestation, than other sub-sectors."
}
],
"4": [
{
"ref_page": "139",
"relevant_info": "Soil erosion costs European farmers EUR 1.25 billion a year."
}
],
"6": [
{
"ref_page": "136",
"relevant_info": "Agriculture is the number one driver of biodiversity loss globally and contributes to one third of global emissions."
}
]
}
}

# %%
methodological_framework_part3 = {
"document_name": "2024_study_for_a_methodological_framework_and_assessment_0_part3.pdf",
"quotes": {
"1": [
{
"ref_page": "159",
"relevant_info": "Land use change is identified as a key risk driver that contributes to biodiversity loss and ecosystem degradation."
}
],
"2": [
{
"ref_page": "215",
"relevant_info": "Pesticide and fertilizers use per ton of products are collected as data to assess impacts, indicating the use of potentially dangerous agrochemicals."
}
],
"3": [
{
"ref_page": "165",
"relevant_info": "Policy and regulatory reviews include restrictions on fertilizer use, highlighting concerns about over‑application and eutrophication."
}
],
"4": [
{
"ref_page": "158",
"relevant_info": "Soil erosion risk in France is assessed using publicly available sources such as the EEA database."
}
]
}
}

# %%
parts = [methodological_framework_part1, methodological_framework_part2, methodological_framework_part3]
quotes = {}
for i in range(1, 12):
    quote_list = []
    for part in parts:
        if str(i) in part["quotes"].keys():
            quote_list += part["quotes"][str(i)]
    quotes[i] = quote_list



methodological_framework = {"document_name": "2024_study_for_a_methodological_framework_and_assessment_0.pdf",
        "quotes":quotes}

# %% [markdown]
# # V2

# %%
keywords = ['land_use', 'land_deg', 'fert', 'pest', 'monoc', 'transp', 'depend']

# %% [markdown]
# ## IPBES Global Assessment Report on Biodiversity and Ecosystem Services

# %%
ipbes1={
"document_title": "The Global Assessment Report on Biodiversity and Ecosystem Services",
"quotes": {
"land_use": [
{
"ref_page": "201",
"relevant_info": "Land‑use change is the direct driver with the largest relative impact on nature since 1970, followed by direct exploitation, in particular overexploitation, of animals, plants and other organisms, mainly via harvesting, logging, hunting and fishing."
},
{
"ref_page": "201",
"relevant_info": "Land‑use change is driven primarily by agriculture, forestry and urbanisation, all of which are associated with air, water and soil pollution."
}
],
"land_deg": [
{
"ref_page": "201",
"relevant_info": "Soil degradation has reduced productivity in 23 per cent of the global terrestrial area."
}
],
"fert": [
{
"ref_page": "201",
"relevant_info": "Excessive or inappropriate application of fertilizer can lead to run‑off from fields and enter freshwater and coastal ecosystems, producing more than 400 hypoxic zones that affected a total area of more than 245,000 km2 as early as 2008."
}
]
}
}

ipbes2 = {
"document_title": "The Global Assessment Report on Biodiversity and Ecosystem Services",
"quotes": {
"land_use": [
{
"ref_page": "119",
"relevant_info": "Over half the Earth’s land surface is under cover types of anthropic origin, including agricultural lands, pasture and cities (Foley et al., 2005; Hooke et al., 2012)."
},
{
"ref_page": "119",
"relevant_info": "Agricultural expansion is by far the most widespread form of land‑cover change, with over one third of the terrestrial land surface currently being used for cropping or animal husbandry at the expense of forests, wetlands, prairies and many other natural land‑cover types (FAO, 2016a; Foley et al., 2005)."
}
],
"land_deg": [
{
"ref_page": "120",
"relevant_info": "Land degradation is the reduction or loss of biological or economic productivity and complexity (including soil erosion, deterioration in physical, chemical, biological or economic properties of soils and long‑term loss of vegetation) of cropland, rangeland, pastureland, forest and woodlands in arid, semi‑arid and dry sub‑humid areas, that results from land uses or a combination of processes, including those arising from human activities and habitation patterns (IPBES, 2018a)."
}
],
"fert": [
{
"ref_page": "124",
"relevant_info": "Fertilizer use rose fourfold in only 13 years in Asia and the Pacific, and doubled in developing countries, contributing to eutrophication of water bodies (Figure S20)."
}
],
"pest": [
{
"ref_page": "124",
"relevant_info": "Pesticides are a major source of water contamination and contribute to loss of biodiversity in aquatic ecosystems (Section 2.1.15.2)."
}
],
"monoc": [
{
"ref_page": "112",
"relevant_info": "Monocultures have yielded poorer diets than traditional farming and have contributed to biodiversity loss, reducing the resilience of food‑production systems."
}
],
"transp": [
{
"ref_page": "108",
"relevant_info": "Transportation of goods and people has risen drastically, accounting for about 15 % of global CO₂ emissions, and landfills emit methane, a potent greenhouse gas (Section 2.1.11.8)."
}
],
"depend": [
{
"ref_page": "86",
"relevant_info": "A few corporations and/or financiers often control large shares of the flows in any market, with some companies rivaling the revenues of entire national economies (Section 2.1.6.2)."
}
]
}
}

ipbes3={
"document_title": "IPBES Global Assessment Report on Biodiversity and Ecosystem Services – Chapter 2.2 Status and Trends – Nature",
"quotes": {
"land_use": [
{
"ref_page": "206",
"relevant_info": "Over 30% of the world’s land is now agricultural or urban, with ecosystem processes deliberately redirected from natural to anthropogenic pathways."
},
{
"ref_page": "206",
"relevant_info": "Land‑use change is the most common direct driver threatening assessed species, followed by (in descending order of prevalence) direct exploitation, pollution, invasive alien species and climate change."
}
],
"land_deg": [
{
"ref_page": "231",
"relevant_info": "Land degradation – of which soil erosion is but one facet – is a global problem, affecting all land systems in all countries, but there is no quantitative consensus on its extent or trend (IPBES, 2018): e.g., estimates of the still undegraded fraction of the land surface range from 75.8 % to 96.8 % (Gibbs & Salmon, 2015)."
},
{
"ref_page": "231",
"relevant_info": "35.9 Pg of soil was lost to erosion in 2012, 2.5 % more than in 2001 (Borrelli et al., 2017)."
}
]
}
}

ipbes4={
"document_title": "202206_IPBES GLOBAL REPORT_FULL_DIGITAL_MARCH 2022.pdf",
"quotes": {
"land_use": [
{
"ref_page": "312-313",
"relevant_info": "Land‑use change … has caused a reduction in the area of forests, grasslands, and other natural habitats."
}
],
"land_deg": [
{
"ref_page": "329",
"relevant_info": "Soil degradation has reduced agricultural productivity on 23 % of the global terrestrial area and affects 3.2 billion people (IPBES, 2018a)."
},
{
"ref_page": "329-330",
"relevant_info": "Globally, the world has lost an estimated 8 % of total global soil carbon since the 1970s."
}
],
"fert": [
{
"ref_page": "327",
"relevant_info": "Nutrient loading from anthropogenic sources, particularly agriculture and wastewater, has increased dramatically over the past 50 years, leading to increased eutrophication (Smith et al., 2003; UNEP, 2016)."
}
],
"pest": [
{
"ref_page": "332",
"relevant_info": "Chemical controls such as herbicides and pesticides have increased by 15–20 % (Oerke, 2006), often substituting or replacing pest and disease regulating NCP."
}
]
}
}

ipbes5={
"document_title": "202206_IPBES GLOBAL REPORT_FULL_DIGITAL_MARCH 2022-1.pdf",
"quotes": {
"land_use": [
{
"ref_page": "410",
"relevant_info": "Agricultural expansion is one of the main drivers of global biodiversity loss (Eisner et al., 2016; UNCTAD, 2013)."
},
{
"ref_page": "410",
"relevant_info": "Annual tree cover loss derived from globally consistent analysis of remote sensing data increased from 17.2 ± 0.63 million ha/yr in 2001–2010 to 21.3 ± 1.78 million ha/yr in 2011–2016 (globalforestwatch.org; Harris et al., 2016)."
}
],
"land_deg": [
{
"ref_page": "413",
"relevant_info": "soil degradation, erosion, impoverishment of soil biota (Gianinazzi et al., 2010)"
},
{
"ref_page": "413",
"relevant_info": "soil erosion is a global problem (IPBES, 2018a)."
}
],
"fert": [
{
"ref_page": "411",
"relevant_info": "Nitrogen pollution causes widespread plant biodiversity loss … eutrophication of aquatic ecosystems (Bobbink et al., 2010; …)."
},
{
"ref_page": "402",
"relevant_info": "Nitrogen surplus (Tg N) Medium Significant increase"
}
],
"pest": [
{
"ref_page": "402",
"relevant_info": "Pesticide use (tonnes) Medium Significant increase"
}
],
"monoc": [
{
"ref_page": "413",
"relevant_info": "monoculture‑based agriculture with high levels of external inputs include soil degradation and erosion, impoverishment of soil biota (Gianinazzi et al., 2010)."
}
]
}
}

ipbes6={
"document_title": "THE GLOBAL ASSESSMENT REPORT ON BIODIVERSITY AND ECOSYSTEM SERVICES",
"quotes": {
"land_use": [
{
"ref_page": "Section 3.3.2",
"relevant_info": "Industrial agriculture … land‑use change, land degradation and desertification, together …"
},
{
"ref_page": "Section 3.3.2",
"relevant_info": "Industrial agriculture … land‑use change …"
}
],
"land_deg": [
{
"ref_page": "Section 3.3.2",
"relevant_info": "Industrial agriculture … erodes and degrades the soil."
},
{
"ref_page": "Section 3.3.2",
"relevant_info": "Soil erosion … is a major cause of land‑use change, land degradation and desertification."
}
],
"fert": [
{
"ref_page": "Section 3.3.2",
"relevant_info": "Industrial agriculture … overuse of fertilizers … leads to water pollution and eutrophication."
},
{
"ref_page": "Section 3.3.2",
"relevant_info": "High N and P loads can indicate organic pollution levels that risk eutrophication."
}
],
"pest": [
{
"ref_page": "Section 3.3.2",
"relevant_info": "Industrial agriculture … overuse of pesticides … pollute the water and soil, and bring harm to the ecosystem."
},
{
"ref_page": "Section 3.3.2",
"relevant_info": "Pesticides … contribute to water and soil pollution."
}
]
}
}

ipbes7={
"document_title": "The Global Assessment Report on Biodiversity and Ecosystem Services (2022)",
"quotes": {
"land_use": [
{
"ref_page": "503",
"relevant_info": "human activities happen on land, from agriculture to urbanization, among others."
},
{
"ref_page": "503",
"relevant_info": "major drivers of land use change have been the impacts of urbanization and increasing consumption, which has resulted in high ecological footprints with increasing pressures on all resources."
}
]
}
}

ipbes8={
"document_title": "202206_IPBES GLOBAL REPORT_FULL_DIGITAL_MARCH 2022",
"quotes": {
"land_use": [
{
"ref_page": "602",
"relevant_info": "Land‑use and land‑cover changes have direct and large impacts on the physical environment. They include expansion of crops and pastures, as well as intensification and management changes, mineral and biomass extraction, urbanization and infrastructure expansion (Geist & Lambin, 2002)."
}
],
"land_deg": [
{
"ref_page": "664",
"relevant_info": "Soil erosion ... is a major driver of land degradation, with intensified agriculture and pesticide use accelerating loss of topsoil."
}
],
"fert": [
{
"ref_page": "665",
"relevant_info": "Fertilizer consumption (in Tg N and P) ... shows a rapid increase in nitrogen and phosphorus inputs to ecosystems, contributing to nutrient loading and eutrophication."
}
],
"pest": [
{
"ref_page": "664",
"relevant_info": "Intensive agricultural management and pesticide use, environmental pollution, invasive alien species, pathogens and climate change ..."
}
]
}
}

ipbes9={
"document_title": "202206_IPBES GLOBAL REPORT_FULL_DIGITAL_MARCH 2022.pdf",
"quotes": {
"land_use": [
{
"ref_page": "4",
"relevant_info": "Land‑use change … destroy and displace local biodiversity."
}
],
"land_deg": [
{
"ref_page": "5",
"relevant_info": "soil erosion is a major problem"
},
{
"ref_page": "5",
"relevant_info": "soil erosion and degradation"
}
],
"fert": [
{
"ref_page": "6",
"relevant_info": "Fertilizers … water pollution and eutrophication."
}
],
"pest": [
{
"ref_page": "6",
"relevant_info": "Pesticides … pollute the water and soil, and bring harm to the ecosystem."
}
],
"monoc": [
{
"ref_page": "7",
"relevant_info": "monoculture … erodes the soil, contributes to biodiversity loss, makes food production systems less resilient."
}
]
}
}

ipbes10={
"document_title": "IPBES Global Assessment Report – Chapter 5: Pathways Towards a Sustainable Future",
"quotes": {
"land_use": [
{
"ref_page": "770",
"relevant_info": "Today, agriculture accounts for 38 % of Earth’s terrestrial surface (Foley et al., 2011) and produces enough calories for all people in the world."
},
{
"ref_page": "770",
"relevant_info": "Agriculture is a fundamental driver of global biodiversity loss through its area expansion and the increase of pollutants and of resources used in production."
}
],
"pest": [
{
"ref_page": "795",
"relevant_info": "Industrial agriculture – input‑intensive monocultures and industrial‑scale feedlots currently dominate farming landscapes… chemical fertilizers, pesticides and preventive use of antibiotics."
}
],
"monoc": [
{
"ref_page": "795",
"relevant_info": "Industrial agriculture – input‑intensive monocultures and industrial‑scale feedlots currently dominate farming landscapes."
},
{
"ref_page": "795",
"relevant_info": "Monocultures often have higher yields… but perform poorly when considering multiple ecosystem services."
}
]
}
}

ipbes11={
"document_title": "IPBES Global Assessment Report on Biodiversity and Ecosystem Services",
"quotes": {
"land_use": [
{
"ref_page": "876-877",
"relevant_info": "Land‑use systems consisting of mosaics of cropland, grasslands and pastures, and forests ... are the space where the largest conflicts with nature conservation take place (Ravenelle & Nyhus, 2017)."
}
],
"land_deg": [
{
"ref_page": "876",
"relevant_info": "Industrial agriculture contributes to soil erosion ... leading to degradation of soil structure and fertility."
}
],
"fert": [
{
"ref_page": "876",
"relevant_info": "Excessive use of fertilizers results in nutrient runoff that causes eutrophication of water bodies."
}
],
"pest": [
{
"ref_page": "876",
"relevant_info": "Pesticide applications contaminate soil and water, posing risks to ecosystems."
}
],
"monoc": [
{
"ref_page": "876",
"relevant_info": "Monoculture practices erode soil, reduce biodiversity, and diminish the resilience of food production systems."
}
],
"transp": [
{
"ref_page": "876",
"relevant_info": "Produce that ends up in landfill generates methane, a potent greenhouse gas."
}
]
}
}

parts=[ipbes1, ipbes2, ipbes3, ipbes4, ipbes5, ipbes6, ipbes7, ipbes8, ipbes9, ipbes10, ipbes11]


quotes = {}
for i in keywords:
    quote_list = []
    for part in parts:
        if str(i) in part["quotes"].keys():
            quote_list += part["quotes"][str(i)]
    quotes[i] = quote_list



ipbes = {"document_name": "IPBES Global Assessment Report on Biodiversity and Ecosystem Services",
        "quotes":quotes}

# %% [markdown]
# ## Study for a methodological framework and assessment of potential financial risks associated with biodiversity loss and ecosystem degradation

# %%
eumeth1={
"document_title": "Study for a methodological framework and assessment of potential financial risks associated with biodiversity loss and ecosystem degradation",
"quotes": {
"land_use": [
{
"ref_page": "8",
"relevant_info": "Risk drivers, the root cause of nature loss, are most commonly described based on the IPBES classification ( 4 ) - land use and climate change, resource use, pollution and invasive aliens’ species."
},
{
"ref_page": "45",
"relevant_info": "Risk driver 1: Land use change (terrestrial and marine/aquatic)… Land use change … is the major human influence on habitats which can include the conversion of land cover (e.g. deforestation or mining), changes in the management of the ecosystem or agro‑ecosystem (e.g. through the intensification of agricultural management or forest harvesting), or changes in the spatial configuration of the landscape (e.g. fragmentation of habitats)."
}
],
"land_deg": [
{
"ref_page": "45",
"relevant_info": "Soil erosion… is a major consequence of intensive land‑use change and contributes to land degradation."
}
],
"fert": [
{
"ref_page": "45",
"relevant_info": "Nitrogen deposition is one of the most important threats, causing eutrophication ‘dead zones’."
}
]
}
}

eumeth2= {
"document_title": "Study for a methodological framework and assessment of potential financial risks associated with biodiversity loss and ecosystem degradation",
"quotes": {
"land_use": [
{
"ref_page": "79-80",
"relevant_info": "Agriculture, food and beverage manufacturing, and construction are, for example much more exposed to nature‑related risks such as deforestation, than other sub‑sectors."
},
{
"ref_page": "136",
"relevant_info": "Agriculture is the number one driver of biodiversity loss globally and contributes to one third of global emissions ( 249 ) ( 250 )."
}
],
"land_deg": [
{
"ref_page": "139",
"relevant_info": "Soil erosion costs European countries EUR 1.25 billion a year."
},
{
"ref_page": "139",
"relevant_info": "soil degradation could result in losses of up to €38 billion annually within Europe ( 256 )."
},
{
"ref_page": "139",
"relevant_info": "Erosion, caused primarily by water and wind, leads to the loss of fertile topsoil, significantly diminishing its productive capacity."
}
]
}
}

eumeth3={
"document_title": "Study for a methodological framework and assessment of potential financial risks associated with biodiversity loss and ecosystem degradation",
"quotes": {
"land_use": [
{
"ref_page": "158",
"relevant_info": "Land use change"
},
{
"ref_page": "210",
"relevant_info": "Land conversion and protected areas"
}
],
"land_deg": [
{
"ref_page": "184",
"relevant_info": "soil erosion risk"
}
],
"fert": [
{
"ref_page": "165",
"relevant_info": "fertilizer use per ton of product"
}
],
"pest": [
{
"ref_page": "165",
"relevant_info": "pesticide and biocides manufacturers"
}
]
}
}

parts = [eumeth1, eumeth2, eumeth3]

quotes = {}
for i in keywords:
    quote_list = []
    for part in parts:
        if str(i) in part["quotes"].keys():
            quote_list += part["quotes"][str(i)]
    if quote_list:
        quotes[i] = quote_list



eumeth = {"document_name": "Study for a methodological framework and assessment of potential financial risks associated with biodiversity loss and ecosystem degradation",
        "quotes":quotes}

# %% [markdown]
# ## Environment, Climate, Plant and Vegetation Growth

# %%
springer1={
"document_title": "Environment, Climate, Plant and Vegetation Growth",
"quotes": {
"land_use": [
{
"ref_page": "Chapter 2, Section 2.8",
"relevant_info": "Land use changes can worsen the effects of land degradation."
},
{
"ref_page": "Chapter 2, Section 2.8",
"relevant_info": "Approximately one‑third of the Earth's land and about half of vegetated land is used for food production."
}
],
"land_deg": [
{
"ref_page": "Chapter 2, Section 2.8",
"relevant_info": "Land degradation comprises water and wind erosion, chemical degradation such as soil acidity and salinity, nutrients leaching, etc."
},
{
"ref_page": "Chapter 2, Section 2.8",
"relevant_info": "Land degradation is a major issue in the twenty‑first century due to its hostile impacts on land, environment, and on the food security of increasing population."
},
{
"ref_page": "Chapter 2, Section 2.8",
"relevant_info": "Land degradation is defined as the deleterious loss of land functions, either partially or totally, resulting from modifications of its properties by humans (FAO 2015a)."
},
{
"ref_page": "Chapter 2, Section 2.8",
"relevant_info": "Land degradation, in turn, refers to a deterioration of soil quality over time, affecting the capacity of a given piece of land..."
}
],
"fert": [
{
"ref_page": "Chapter 6, Section 6.5.5",
"relevant_info": "Fertilizer overuse leads to nitrate leaching."
}
],
"pest": [
{
"ref_page": "Chapter 6, Section 6.5.5",
"relevant_info": "Pesticides pollute the water and soil, and bring harm to the ecosystem."
}
]
}
}

springer2=

# %% [markdown]
# ## The State of the World’s Land and Water Resources for Food and Agriculture 2025

# %%
state_resources = {
"document_title": "The State of the World’s Land and Water Resources for Food and Agriculture 2025",
"quotes": {
"land_use": [
{
"ref_page": "Chapter 1",
"relevant_info": "Agricultural expansion drives nearly 90 percent of global deforestation (FAO, 2022b) and is a primary cause of the degradation of carbon‑rich ecosystems such as peatlands (UNEP, 2022)."
},
{
"ref_page": "Chapter 1",
"relevant_info": "Human‑induced land degradation affects cropland, pastures and forested land. Agriculture … leads to loss of biodiversity, other ecosystem functions and services, and the quality and quantity of land and water resources."
},
{
"ref_page": "Chapter 3",
"relevant_info": "The expansion of agriculture into forest is not a strategic option. This report proposes alternative areas for expansion to enhance sustainable food production and, at the same time, safeguard forest and protected areas."
}
],
"land_deg": [
{
"ref_page": "Core Messages",
"relevant_info": "More than 1 660 Mha of land, corresponding to more than 10 percent of the world’s land area, have been degraded by unsustainable land‑use and management practices, and more than 60 percent of this degradation occurs on agricultural lands (including cropland and pastureland)."
},
{
"ref_page": "Chapter 1",
"relevant_info": "82 Mha of rainfed cropland and 24 Mha of irrigated cropland are degraded from salinization processes alone (FAO, 2024a)."
},
{
"ref_page": "Chapter 1",
"relevant_info": "Human‑induced land degradation leads to loss of habitat and a decline in species diversity, negatively impacting ecosystems."
}
],
"fert": [
{
"ref_page": "Chapter 2",
"relevant_info": "In 2022, the overall agricultural use of chemical fertilizers was 35 percent higher than in 2001 (FAO, 2025a)."
},
{
"ref_page": "Chapter 1",
"relevant_info": "Positive balances indicate excess application of nitrogen compared with the part that is extracted from the soil by crops (overload). Excessive use of nitrogen fertilizers in most regions leads to soil and water pollution."
},
{
"ref_page": "Chapter 1",
"relevant_info": "Rising prices, market constraints and geopolitical conflicts contribute to limiting the availability of fertilizers to farmers, leading to additional nutrient mining in already depleted soils (Smith et al., 2024)."
}
],
"pest": [
{
"ref_page": "Chapter 1",
"relevant_info": "The inappropriate use of pesticides poses a serious threat to food safety and contributes to the decline in biodiversity by harming soil micro‑biota, ... ."
},
{
"ref_page": "Chapter 1",
"relevant_info": "64 percent of agricultural land is at risk of pesticide pollution (Tang et al., 2021)."
},
{
"ref_page": "Chapter 1",
"relevant_info": "Pesticides whose ingredients include per‑ and poly‑fluoroalkyl substances (PFAS), known as “forever chemicals”, can lead to significant economic losses in the event of contaminated food recalls and health hazards (Donley et al., 2024)."
}
]
}
}

# %% [markdown]
# # Data processing

# %%
import pandas as pd

# %% [markdown]
# # V1

# %%
problem_map = {
    "1":"land_use",
    "2":"pesticide_use",
    "3":"fertilizer_use",
    "4":"soil_erotion",
    "5":"monoculture",
    "6":"store_transport",
    "7":"landfill_transport",
    "8":"anaerobic_decomposition",
    "9":"industrial_dependency",
    "10":"monoculture_vulnerability",
    "11":"production_inefficiencies",
}



sources = [FAO_2025_STATE_OF_FOOD_AND_AGRICULTURE, ipbes, uniformimy_to_diversity, food_from_somewhere, methodological_framework]

sources_df = pd.DataFrame()

source_name_list = []
quote_cat_list = []
quote_page_list = []
quote_list = []

for source in sources:
    source_count = 0
    for category in source["quotes"]:
        for quote in source["quotes"][category]:
            quote_page_list += [quote["ref_page"]]
            quote_list += [quote["relevant_info"]]
            source_count += 1 
        quote_cat_list += [str(category)]*len(source["quotes"][category])

    source_name_list += [source["document_name"]]*source_count

sources_df["source_doc"] = source_name_list
sources_df["problem_category"] = quote_cat_list
sources_df["quote_page"] = quote_page_list
sources_df["quote"] = quote_list

sources_df["problem_category"] = sources_df["problem_category"].map(problem_map).fillna(sources_df["problem_category"])

sources_df
# Out:
#                                             source_doc problem_category  \
# 0               2025_STATE_OF_FOOD_AND_AGRICULTURE.pdf         land_use
# 1               2025_STATE_OF_FOOD_AND_AGRICULTURE.pdf         land_use
# 2               2025_STATE_OF_FOOD_AND_AGRICULTURE.pdf    pesticide_use
# 3               2025_STATE_OF_FOOD_AND_AGRICULTURE.pdf   fertilizer_use
# 4               2025_STATE_OF_FOOD_AND_AGRICULTURE.pdf   fertilizer_use
# ..                                                 ...              ...
# 116  2024_study_for_a_methodological_framework_and_...   fertilizer_use
# 117  2024_study_for_a_methodological_framework_and_...   fertilizer_use
# 118  2024_study_for_a_methodological_framework_and_...     soil_erotion
# 119  2024_study_for_a_methodological_framework_and_...     soil_erotion
# 120  2024_study_for_a_methodological_framework_and_...  store_transport
#
#     quote_page                                              quote
# ...

# %%
{"source_doc": "2024_study_for_a_methodological_framework_and_assessment_0.pdf",
"example_bibtex" : """
@INCOLLECTION{Cziesielski2024-vu,
  booktitle = "Study for a methodological framework and assessment of potential
               financial risks associated with biodiversity loss and ecosystem
               degradation final report",
  author    = "Cziesielski, M and Dekker-Hufler, C and Pal, T and Nicholls, G
               and Petsinaris, F and Korteweg, L and Obersteiner, M and
               Khabarov, N",
  year      =  {2024}
}
"""
}

{"source_doc": "FoodFromSomewhere.pdf",
"example_bibtex" : """
@incollection{ipesfood2024_chapter3,
  author       = {Jane Battersby and Million Belay and Jennifer Clapp and Shalmali Guttal and Phil Howard and Pat Mooney and Raj Patel and Anna Paskal and Nick Jacobs and Susan Alexander and Flavio Bladimir Rodriguez Muñoz and Raj Shekhar and Ines Tielas da Silva and Pablo Thorne and Oriana Lopez and Isabella Steinhauer and Fernanda Caceres and David Cruz and David Freid and Kathleen Hillery and Emily Ibarra and Jamie Kim and Dreek Morgan and Sabrina Page and Michael Santulli and Christian Widjaja},
  editor       = {IPES-Food},
  booktitle    = {Food from Somewhere: Building Food Security and Resilience through Territorial Markets},
  year         = {2024},
  month        = jul,
  publisher    = {IPES-Food},
  address      = {Berlin, Germany},
  url          = {https://ipes-food.org/publications/food-from-somewhere},
}
"""
}

{"source_doc": "UniformityToDiversity_FULL.pdf",
"example_bibtex" : """
@report{IPESFood_2016_UniformityToDiversity,
  author       = {Frison, Emile A. and Jacobs, Nick},
  title        = {From Uniformity to Diversity: A Paradigm Shift from Industrial Agriculture to Diversified Agroecological Systems},
  institution  = {International Panel of Experts on Sustainable Food Systems (IPES-Food)},
  year         = {2016},
  month        = jun,
  type         = {Report},
  url          = {https://www.ipes-food.org/images/Reports/UniformityToDiversity_FullReport.pdf},
}
"""
}


{"source_doc": "202206_IPBES GLOBAL REPORT_FULL_DIGITAL_MARCH 2022.pdf",
"example_bibtex" : """
@book{Brondízio_Settele_Díaz_Ngo_2019, 
  place={Bonn}, 
  title={The Global Assessment Report of the intergovernmental science-policy platform on biodiversity and ecosystem services}, 
  publisher={Intergovernmental Science-Policy Platform on Biodiversity and Ecosystem Services (IPBES)}, 
  author={Brondízio, Eduardo Sonnewend and Settele, Josef and Díaz, Sandra and Ngo, Hien Thu}, 
  year={2019}} 
"""
}

{"source_doc": "2025_STATE_OF_FOOD_AND_AGRICULTURE.pdf",
"example_bibtex" : """
@MISC{fao_2025-ka,
  title     = "The state of food and agriculture 2025",
  publisher = "FAO",
  month     =  nov,
  year      =  2025,
  language  = "en"
}
"""
}
# Out:
# {'source_doc': '2025_STATE_OF_FOOD_AND_AGRICULTURE.pdf',
#  'example_bibtex': '\n@MISC{fao_2025-ka,\n  title     = "The state of food and agriculture 2025",\n  publisher = "FAO",\n  month     =  nov,\n  year      =  2025,\n  language  = "en"\n}\n'}

# %%
sources_df.to_csv("quotes.csv")
